# %% [markdown]
# # Example 08: PyTorch Parameter-optimization with Optuna

# %% [markdown]
# ## 事前準備

# %%
import torch

# GPUが使えるか確認してデバイスを設定
# NOTE: `x = x.to(device) ` とすることで対象のデバイスに切り替え可能
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## CNN

# %%
import optuna
import torch
import torchinfo
from torch import nn
from torch import optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import transforms
from torchvision.datasets import CIFAR10
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt

# %% [markdown]
# ### DataLoader設定

# %%
# transformを準備
affine = transforms.RandomAffine((-30, 30), scale=(0.8, 1.2))
flip = transforms.RandomHorizontalFlip(p=0.5)
normalize = transforms.Normalize((0.0, 0.0, 0.0), (1.0, 1.0, 1.0))  # 平均0、標準偏差1

transform_train = transforms.Compose([
    affine,
    flip,
    transforms.ToTensor(),
    normalize
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    normalize
])

# %%
# DataLoader作成
cifar10_train = CIFAR10(root='../cache/data', train=True, download=True, transform=transform_train)
cifar10_test = CIFAR10(root='../cache/data', train=False, download=True, transform=transform_test)
cifar10_classes = cifar10_train.classes

# %%
# DataLoaderの設定
batch_size = 128
train_loader = DataLoader(cifar10_train, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(cifar10_test, batch_size=batch_size, shuffle=False)

# %%
len(cifar10_train), len(cifar10_test)
# Out:
# (50000, 10000)

# %% [markdown]
# ### モデル構築
#
# `dropout_prob`, `activation_func` を自動チューニングするため、コンストラクタで設定できるようにモデルクラスを作成する。

# %%
class Net(nn.Module):
    def __init__(self, n_classes: int,
                       dropout_prob: float = 0.5,
                       activation_func: nn.Module = nn.ReLU()):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 8, 5)         # 入力チャネル、出力チャネル、フィルタ数
        self.active = activation_func
        self.pool = nn.MaxPool2d(2, 2)          # 領域のサイズ、領域の間隔
        self.conv2 = nn.Conv2d(8, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 256)
        self.dropout = nn.Dropout(dropout_prob)          # ドロップアウト率
        self.fc2 = nn.Linear(256, n_classes)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.active(self.conv1(x))
        x = self.pool(x)
        x = self.active(self.conv2(x))
        x = self.pool(x)
        x = x.view(-1, 16 * 5 * 5)
        x = self.active(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
net = Net(len(cifar10_classes))

# %% [markdown]
# ### 訓練 & 検証用関数を作成
#
# 自動パラメータチューニングで作成するoptunaの目的関数で使用するため、訓練 & 検証用の関数を作成する。

# %%
def train(net: nn.Module, train_loader: DataLoader, optimizer: optim.Optimizer, criterion: nn.Module = nn.CrossEntropyLoss(), verbose: bool = True) -> float:
    net.train()
    loss_train = 0.0

    # verbose がTrueの場合はプログレスバーを表示する
    iterator = tqdm(train_loader) if verbose else train_loader
    
    for (x, t) in iterator:
        x, t = x.to(device), t.to(device)
        y = net(x)

        loss = criterion(y, t)
        loss_train += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    loss_train /= len(train_loader)
    return loss_train

# %%
def test(net: nn.Module, test_loader: DataLoader, criterion: nn.Module = nn.CrossEntropyLoss(), verbose: bool = True) -> float:
    net.eval()
    loss_test = 0.0

    # verbose がTrueの場合はプログレスバーを表示する
    iterator = tqdm(train_loader) if verbose else train_loader
    
    for (x, t) in iterator:
        x, t = x.to(device), t.to(device)
        y = net(x)

        loss = criterion(y, t)
        loss_test += loss.item()

    loss_test /= len(test_loader)
    return loss_test

# %% [markdown]
# ### 自動チューニング設定(optuna)
#
# 今回は以下のパラメータをチューニング対象とする。
#
# - 最適化アルゴリズム
# - 活性化関数
# - ドロップアウト率

# %% [markdown]
# #### Optimizer

# %%
def get_adam_optimizer(trial: optuna.trial.Trial, model: nn.Module) -> optim.Optimizer:
    lr = trial.suggest_float('adam_lr', 1e-5, 1e-1, log=True)
    weight_decay = trial.suggest_float('adam_weight_decay', 1e-10, 1e-3)
    optimizer = optim.Adam(model.parameters(),
                           lr=lr,
                           weight_decay=weight_decay)
    return optimizer

def get_momentum_sgd_optimizer(trial: optuna.trial.Trial, model: nn.Module) -> optim.Optimizer:
    lr = trial.suggest_float('momentum_sgd_lr', 1e-5, 1e-1, log=True)
    weight_decay = trial.suggest_float('momentum_sgd_weight_decay', 1e-10, 1e-3, log=True)
    optimizer = optim.SGD(model.parameters(),
                          lr=lr,
                          momentum=0.9,
                          weight_decay=weight_decay)
    return optimizer

def get_rms_prob_optimizer(trial: optuna.trial.Trial, model: nn.Module) -> optim.Optimizer:
    lr = trial.suggest_float('rms_prob_lr', 1e-5, 1e-1, log=True)
    optimizer = optim.RMSprop(model.parameters(), lr=lr)
    return optimizer

# %%
def get_optimizer(trial: optuna.trial.Trial, model: nn.Module) -> optim.Optimizer:
    optimizer_names = ['Adam', 'MomentumSGD', 'rmsprop']
    optimizer_name = trial.suggest_categorical('optimizer', optimizer_names)
    
    if optimizer_name == 'Adam': 
        optimizer = get_adam_optimizer(trial, model)
    elif optimizer_name == 'MomentumSGD':
        optimizer = get_momentum_sgd_optimizer(trial, model)
    else:
        optimizer = get_rms_prob_optimizer(trial, model)
    
    return optimizer

# %% [markdown]
# #### 活性化関数

# %%
def get_activation(trial: optuna.trial.Trial) -> nn.Module:
    activation_names = ['ReLU', 'Tanh']
    activation_name = trial.suggest_categorical('activation', activation_names)
    
    if activation_name == 'ReLU':
        activation = nn.ReLU()
    else:
        activation = nn.Tanh()
    return activation

# %% [markdown]
# #### 目的関数(クラス)の定義
#
# 評価時の誤り率を最小化するような目的関数を作成する。

# %%
class Objective:
    def __init__(self, n_traial: int, train_loader: DataLoader, test_loader: DataLoader, n_class: int, n_epoch: int = 10):
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.n_class = n_class
        self.n_epoch = n_epoch
        self.progress_bar = tqdm(total=n_traial)
        
    def __call__(self, trial: optuna.trial.Trial) -> float:
        dropout_prob = trial.suggest_float("dropout_prob", 0.2, 0.8, step=0.1)
        activation = get_activation(trial)
  
        net = Net(self.n_class, dropout_prob, activation).to(device)
        optimizer = get_optimizer(trial, net)

        criterion = nn.CrossEntropyLoss()
        
        for epoch in range(self.n_epoch):
            train(net, train_loader, optimizer, criterion, verbose=False)
            loss = test(net, test_loader, criterion, verbose=False)
        
        self.progress_bar.update(1)
        
        return loss

# %% [markdown]
# ### 自動チューニング実施(optuna)

# %%
n_trials = 30

n_epoch = 10
n_class = len(cifar10_classes)

# %%
# 誤り率の最小化を行うため、direction='minimize'に設定
objective = Objective(n_trials, train_loader, test_loader, n_class, n_epoch)
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=n_trials)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-08-22 00:43:47,336] A new study created in memory with name: no-name-22aca879-1f2e-4856-897a-29f5915adc6f
# [I 2025-08-22 00:46:01,474] Trial 0 finished with value: 11.87208314183392 and parameters: {'dropout_prob': 0.2, 'activation': 'Tanh', 'optimizer': 'rmsprop', 'rms_prob_lr': 0.005442623693178118}. Best is trial 0 with value: 11.87208314183392.
# [I 2025-08-22 00:48:15,549] Trial 1 finished with value: 8.583642515955091 and parameters: {'dropout_prob': 0.8, 'activation': 'ReLU', 'optimizer': 'Adam', 'adam_lr': 5.379379269473184e-05, 'adam_weight_decay': 0.0008491901632931595}. Best is trial 1 with value: 8.583642515955091.
# [I 2025-08-22 00:50:27,046] Trial 2 finished with value: 9.786721526821957 and parameters: {'dropout_prob': 0.7, 'activation': 'ReLU', 'optimizer': 'Adam', 'adam_lr': 1.4116438789115086e-05, 'adam_weight_decay': 0.000986737591616569}. Best is trial 1 with value: 8.583642515955091.
# [I 2025-08-22 00:52:39,358] Trial 3 finished with value: 7.5367707315879535 and parameters: {'dropout_prob': 0.4, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 0.002193412676955972, 'momentum_sgd_weight_decay': 4.330590271317986e-06}. Best is trial 3 with value: 7.5367707315879535.
# [I 2025-08-22 00:54:51,106] Trial 4 finished with value: 9.564302082303204 and parameters: {'dropout_prob': 0.4, 'activation': 'Tanh', 'optimizer': 'rmsprop', 'rms_prob_lr': 1.0310844997923037e-05}. Best is trial 3 with value: 7.5367707315879535.
# [I 2025-08-22 00:57:03,859] Trial 5 finished with value: 11.392986692959749 and parameters: {'dropout_prob': 0.30000000000000004, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 1.948352646670642e-05, 'momentum_sgd_weight_decay': 9.847555338279074e-08}. Best is trial 3 with value: 7.5367707315879535.
# [I 2025-08-22 00:59:15,406] Trial 6 finished with value: 12.765450184858299 and parameters: {'dropout_prob': 0.30000000000000004, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.07221017651184665, 'adam_weight_decay': 0.00022708223503942342}. Best is trial 3 with value: 7.5367707315879535.
# [I 2025-08-22 01:01:27,470] Trial 7 finished with value: 9.092725148683861 and parameters: {'dropout_prob': 0.5, 'activation': 'ReLU', 'optimizer': 'rmsprop', 'rms_prob_lr': 2.7290030925805202e-05}. Best is trial 3 with value: 7.5367707315879535.
# [I 2025-08-22 01:03:39,489] Trial 8 finished with value: 7.092459610745877 and parameters: {'dropout_prob': 0.5, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 0.00407235682794334, 'momentum_sgd_weight_decay': 1.9218709841093923e-09}. Best is trial 8 with value: 7.092459610745877.
# [I 2025-08-22 01:05:52,080] Trial 9 finished with value: 7.1473919771894625 and parameters: {'dropout_prob': 0.4, 'activation': 'ReLU', 'optimizer': 'Adam', 'adam_lr': 0.0002717241879563607, 'adam_weight_decay': 0.00033769961406493937}. Best is trial 8 with value: 7.092459610745877.
# [I 2025-08-22 01:08:04,001] Trial 10 finished with value: 8.8378046147431 and parameters: {'dropout_prob': 0.6000000000000001, 'activation': 'Tanh', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 0.06364064272951189, 'momentum_sgd_weight_decay': 1.0263463419957489e-10}. Best is trial 8 with value: 7.092459610745877.
# [I 2025-08-22 01:10:15,837] Trial 11 finished with value: 6.419107213804994 and parameters: {'dropout_prob': 0.5, 'activation': 'ReLU', 'optimizer': 'Adam', 'adam_lr': 0.0015803858380146847, 'adam_weight_decay': 3.315914122482323e-05}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:12:28,822] Trial 12 finished with value: 7.360645289662518 and parameters: {'dropout_prob': 0.6000000000000001, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 0.0029673404133914176, 'momentum_sgd_weight_decay': 1.0905026081403627e-09}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:14:41,136] Trial 13 finished with value: 7.860446125646181 and parameters: {'dropout_prob': 0.6000000000000001, 'activation': 'ReLU', 'optimizer': 'Adam', 'adam_lr': 0.0064905186547441615, 'adam_weight_decay': 2.952656576968104e-05}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:16:53,811] Trial 14 finished with value: 11.353548581087136 and parameters: {'dropout_prob': 0.5, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 9.264663544689728e-05, 'momentum_sgd_weight_decay': 0.00034057128733267785}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:19:05,252] Trial 15 finished with value: 7.144434317757812 and parameters: {'dropout_prob': 0.7, 'activation': 'ReLU', 'optimizer': 'Adam', 'adam_lr': 0.002893398866222736, 'adam_weight_decay': 0.000552363519941773}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:21:16,508] Trial 16 finished with value: 6.585788384268556 and parameters: {'dropout_prob': 0.5, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 0.032738714067790435, 'momentum_sgd_weight_decay': 1.6398230382347012e-08}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:23:29,324] Trial 17 finished with value: 8.389603711381744 and parameters: {'dropout_prob': 0.5, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 0.06860842983500444, 'momentum_sgd_weight_decay': 2.1872332828400813e-07}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:25:42,283] Trial 18 finished with value: 6.734989978090117 and parameters: {'dropout_prob': 0.30000000000000004, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.0005753231112744916, 'adam_weight_decay': 0.0006039343760233451}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:27:53,682] Trial 19 finished with value: 11.439411685436587 and parameters: {'dropout_prob': 0.7, 'activation': 'ReLU', 'optimizer': 'rmsprop', 'rms_prob_lr': 0.0819850364369368}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:30:06,538] Trial 20 finished with value: 6.8253632104849515 and parameters: {'dropout_prob': 0.8, 'activation': 'ReLU', 'optimizer': 'MomentumSGD', 'momentum_sgd_lr': 0.01587393800040945, 'momentum_sgd_weight_decay': 1.3489383052822081e-05}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:32:19,493] Trial 21 finished with value: 6.668511016459405 and parameters: {'dropout_prob': 0.2, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.0005944692575510036, 'adam_weight_decay': 0.0006131818556639906}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:34:32,883] Trial 22 finished with value: 7.1509190933613835 and parameters: {'dropout_prob': 0.2, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.0070184607760404175, 'adam_weight_decay': 0.0007151189482351531}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:36:46,177] Trial 23 finished with value: 7.081545855425581 and parameters: {'dropout_prob': 0.4, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.00024270974985896853, 'adam_weight_decay': 0.00033550593036455693}. Best is trial 11 with value: 6.419107213804994.
# [I 2025-08-22 01:39:02,205] Trial 24 finished with value: 5.834608320948444 and parameters: {'dropout_prob': 0.2, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.0020255100798272398, 'adam_weight_decay': 1.6714355364919236e-05}. Best is trial 24 with value: 5.834608320948444.
# [I 2025-08-22 01:41:14,888] Trial 25 finished with value: 13.988024174412594 and parameters: {'dropout_prob': 0.30000000000000004, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.03278763280029891, 'adam_weight_decay': 1.7594068453170745e-05}. Best is trial 24 with value: 5.834608320948444.
# [I 2025-08-22 01:43:28,139] Trial 26 finished with value: 6.588650890543491 and parameters: {'dropout_prob': 0.6000000000000001, 'activation': 'Tanh', 'optimizer': 'Adam', 'adam_lr': 0.0027953457711251597, 'adam_weight_decay': 0.0001689943881148706}. Best is trial 24 with value: 5.834608320948444.
# 28                       NaN                  0.6                     NaN
# 23                  0.000336                  0.4                     NaN
# 8                        NaN                  0.5                0.004072
# 15                  0.000552                  0.7                     NaN
# 9                   0.000338                  0.4                     NaN
# 22                  0.000715                  0.2                     NaN
# 12                       NaN                  0.6                0.002967
# 3                        NaN                  0.4                0.002193
# 13                  0.000030                  0.6                     NaN
# 17                       NaN                  0.5                0.068608
# 1                   0.000849                  0.8                     NaN
# 10                       NaN                  0.6                0.063641
# 7                        NaN                  0.5                     NaN
# 4                        NaN                  0.4                     NaN
# 2                   0.000987                  0.7                     NaN
# 29                       NaN                  0.2                0.000277
# 14                       NaN                  0.5                0.000093
# 5                        NaN                  0.3                0.000019
# 27                  0.000161                  0.4                     NaN
# 19                       NaN                  0.7                     NaN
# 0                        NaN                  0.2                     NaN
# 6                   0.000227                  0.3                     NaN
# 25                  0.000018                  0.3                     NaN
#
#     params_momentum_sgd_weight_decay params_optimizer  params_rms_prob_lr  \
# 24                               NaN             Adam                 NaN
# 11                               NaN             Adam                 NaN
# 16                      1.639823e-08      MomentumSGD                 NaN
# 26                               NaN             Adam                 NaN
# 21                               NaN             Adam                 NaN
# 18                               NaN             Adam                 NaN
# 20                      1.348938e-05      MomentumSGD                 NaN
# 28                               NaN          rmsprop            0.000334
# 23                               NaN             Adam                 NaN
# 8                       1.921871e-09      MomentumSGD                 NaN
# 15                               NaN             Adam                 NaN
# 9                                NaN             Adam                 NaN
# 22                               NaN             Adam                 NaN
# 12                      1.090503e-09      MomentumSGD                 NaN
# 3                       4.330590e-06      MomentumSGD                 NaN
# 13                               NaN             Adam                 NaN
# 17                      2.187233e-07      MomentumSGD                 NaN
# 1                                NaN             Adam                 NaN
# 10                      1.026346e-10      MomentumSGD                 NaN
# 7                                NaN          rmsprop            0.000027
# 4                                NaN          rmsprop            0.000010
# 2                                NaN             Adam                 NaN
# 29                      1.954772e-08      MomentumSGD                 NaN
# 14                      3.405713e-04      MomentumSGD                 NaN
# 5                       9.847555e-08      MomentumSGD                 NaN
# 27                               NaN             Adam                 NaN
# 19                               NaN          rmsprop            0.081985
# 0                                NaN          rmsprop            0.005443
# 6                                NaN             Adam                 NaN
# 25                               NaN             Adam                 NaN
#
#        state
# 24  COMPLETE
# 11  COMPLETE
# 16  COMPLETE
# 26  COMPLETE
# 21  COMPLETE
# 18  COMPLETE
# 20  COMPLETE
# 28  COMPLETE
# 23  COMPLETE
# 8   COMPLETE
# 15  COMPLETE
# 9   COMPLETE
# 22  COMPLETE
# 12  COMPLETE
# 3   COMPLETE
# 13  COMPLETE
# 17  COMPLETE
# 1   COMPLETE
# 10  COMPLETE
# 7   COMPLETE
# 4   COMPLETE
# 2   COMPLETE
# 29  COMPLETE
# 14  COMPLETE
# 5   COMPLETE
# 27  COMPLETE
# 19  COMPLETE
# 0   COMPLETE
# 6   COMPLETE
# 25  COMPLETE
